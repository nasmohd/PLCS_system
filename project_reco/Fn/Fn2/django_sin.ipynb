# %%
#Imports
import csv
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Step 1: Load data from Users.csv and Projects.csv

# Load user data
users = []
with open('Users.csv', 'r') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip the header row
    for row in reader:
        email = row[0]
        skills = row[1]
        users.append((email, skills))

# %%
users
# Out:
# [('user245@example.com', "['C++ Programming']"),
#  ('user904@example.com',
#   "['C++ Programming', 'UI/UX', 'Algorithm', 'Software Engineering']"),
#  ('user119@example.com',
#   "['Web Application Development', 'UI/UX', 'C++ Programming', 'Algorithm', 'Software Engineering', 'Data Structures']"),
#  ('user506@example.com', "['Algorithm']"),
#  ('user678@example.com',
#   "['Algorithm', 'UI/UX', 'Software Engineering', 'C++ Programming', 'Web Application Development', 'Data Structures']"),
#  ('user851@example.com',
#   "['UI/UX', 'Software Engineering', 'C++ Programming', 'Web Application Development']"),
#  ('user798@example.com', "['Web Application Development', 'UI/UX']"),
#  ('user738@example.com',
#   "['Algorithm', 'UI/UX', 'Software Engineering', 'Data Structures', 'Web Application Development', 'C++ Programming']"),
#  ('user976@example.com',
#   "['C++ Programming', 'UI/UX', 'Algorithm', 'Data Structures', 'Web Application Development']"),
#  ('user869@example.com', "['Web Application Development', 'Algorithm']"),
#  ('user77@example.com', "['Software Engineering']"),
#  ('user502@example.com',
#   "['Web Application Development', 'C++ Programming', 'Software Engineering', 'Algorithm']"),
#  ('user597@example.com', "['UI/UX', 'Web Application Development']"),
#  ('user441@example.com',
#   "['Data Structures', 'UI/UX', 'Web Application Development', 'C++ Programming', 'Software Engineering']"),
#  ('user706@example.com', "['Software Engineering']"),
#  ('user664@example.com',
#   "['Data Structures', 'Web Application Development', 'Software Engineering', 'Algorithm']"),
#  ('user606@example.com',
#   "['Software Engineering', 'Data Structures', 'Web Application Development', 'C++ Programming', 'UI/UX']"),
#  ('user400@example.com',
#   "['Software Engineering', 'C++ Programming', 'Data Structures', 'Algorithm', 'UI/UX']"),
#  ('user847@example.com',
#   "['Data Structures', 'Algorithm', 'C++ Programming']"),
#  ('user354@example.com', "['Data Structures', 'Algorithm']"),
#  ('user188@example.com',
#   "['C++ Programming', 'Web Application Development', 'UI/UX']"),
#  ('user433@example.com', "['Data Structures', 'Algorithm']"),
#  ('user856@example.com',
#   "['UI/UX', 'Web Application Development', 'Software Engineering']"),
#  ('user675@example.com',
#   "['UI/UX', 'Data Structures', 'C++ Programming', 'Web Application Development']"),
#  ('user318@example.com', "['C++ Programming']"),
#  ('user810@example.com', "['Algorithm', 'Data Structures', 'UI/UX']"),
#  ('user897@example.com',
#   "['C++ Programming', 'Web Application Development', 'UI/UX', 'Data Structures', 'Software Engineering']"),
#  ('user227@example.com',
#   "['Software Engineering', 'Web Application Development', 'Data Structures', 'UI/UX', 'C++ Programming', 'Algorithm']"),
#  ('user870@example.com', "['UI/UX', 'C++ Programming']"),
#  ('user707@example.com',
#   "['Algorithm', 'Data Structures', 'Web Application Development']"),
#  ('user383@example.com', "['Data Structures', 'UI/UX']"),
#  ('user697@example.com',
#   "['Web Application Development', 'Software Engineering', 'C++ Programming']"),
#  ('user355@example.com', "['Algorithm']"),
#  ('user239@example.com',
#   "['Web Application Development', 'Software Engineering', 'UI/UX', 'Data Structures', 'Algorithm', 'C++ Programming']"),
#  ('user133@example.com', "['UI/UX', 'Algorithm']"),
#  ('user380@example.com', "['Web Application Development']"),
#  ('user519@example.com',
#   "['Software Engineering', 'Web Application Development', 'Data Structures', 'C++ Programming', 'Algorithm', 'UI/UX']"),
#  ('user619@example.com', "['Data Structures']"),
#  ('user690@example.com', "['Algorithm']"),
#  ('user962@example.com', "['Algorithm']"),
#  ('user637@example.com',
#   "['C++ Programming', 'Software Engineering', 'Web Application Development']"),
#  ('user686@example.com', "['Data Structures']"),
#  ('user791@example.com',
#   "['Data Structures', 'UI/UX', 'Software Engineering', 'Web Application Development', 'C++ Programming']"),
#  ('user231@example.com',
#   "['C++ Programming', 'Software Engineering', 'Data Structures', 'UI/UX', 'Algorithm']"),
#  ('user828@example.com',
#   "['C++ Programming', 'Data Structures', 'Software Engineering', 'UI/UX', 'Web Application Development']"),
#  ('user265@example.com',
#   "['UI/UX', 'Data Structures', 'Software Engineering']"),
#  ('user707@example.com', "['C++ Programming', 'UI/UX', 'Algorithm']"),
#  ('user485@example.com',
#   "['Algorithm', 'Data Structures', 'C++ Programming', 'Web Application Development', 'UI/UX']"),
#  ('user320@example.com',
#   "['C++ Programming', 'Algorithm', 'Software Engineering', 'Data Structures', 'UI/UX', 'Web Application Development']"),
#  ('user171@example.com',
#   "['C++ Programming', 'Algorithm', 'Software Engineering']"),
#  ('user108@example.com', "['Web Application Development', 'Data Structures']"),
#  ('user400@example.com',
#   "['Web Application Development', 'Data Structures', 'C++ Programming']"),
#  ('user838@example.com',
#   "['UI/UX', 'Algorithm', 'Software Engineering', 'C++ Programming', 'Data Structures', 'Web Application Development']"),
#  ('user193@example.com',
#   "['Algorithm', 'Data Structures', 'C++ Programming']"),
#  ('user87@example.com', "['Data Structures', 'Software Engineering']"),
#  ('user484@example.com', "['Web Application Development', 'C++ Programming']"),
#  ('user136@example.com',
#   "['Data Structures', 'Web Application Development', 'UI/UX', 'Software Engineering']"),
#  ('user989@example.com',
#   "['UI/UX', 'Web Application Development', 'Data Structures', 'Algorithm']"),
#  ('user773@example.com', "['UI/UX', 'Algorithm', 'C++ Programming']"),
#  ('user43@example.com',
#   "['Algorithm', 'Data Structures', 'Web Application Development', 'C++ Programming', 'Software Engineering']"),
#  ('user440@example.com',
#   "['UI/UX', 'Software Engineering', 'Algorithm', 'Web Application Development', 'Data Structures', 'C++ Programming']"),
#  ('user427@example.com',
#   "['Data Structures', 'Algorithm', 'Web Application Development', 'C++ Programming']"),
#  ('user857@example.com', "['Data Structures', 'Software Engineering']"),
#  ('user995@example.com',
#   "['UI/UX', 'Software Engineering', 'Data Structures']"),
#  ('user641@example.com',
#   "['Software Engineering', 'Web Application Development', 'Data Structures']"),
#  ('user527@example.com',
#   "['Web Application Development', 'Data Structures', 'C++ Programming', 'Software Engineering']"),
#  ('user622@example.com',
#   "['Data Structures', 'Software Engineering', 'Web Application Development', 'UI/UX', 'Algorithm', 'C++ Programming']"),
#  ('user672@example.com',
#   "['Data Structures', 'Software Engineering', 'Algorithm', 'Web Application Development', 'UI/UX']"),
#  ('user455@example.com', "['Algorithm', 'UI/UX', 'Software Engineering']"),
#  ('user393@example.com',
#   "['UI/UX', 'Data Structures', 'Web Application Development', 'C++ Programming']"),
#  ('user265@example.com', "['Software Engineering', 'Algorithm']"),
#  ('user173@example.com', "['Algorithm']"),
#  ('user255@example.com',
#   "['Algorithm', 'Data Structures', 'Software Engineering', 'C++ Programming', 'Web Application Development']"),
#  ('user742@example.com', "['C++ Programming', 'Data Structures']"),
#  ('user83@example.com',
#   "['Web Application Development', 'UI/UX', 'Algorithm', 'Software Engineering', 'Data Structures', 'C++ Programming']"),
#  ('user978@example.com', "['C++ Programming']"),
#  ('user360@example.com',
#   "['UI/UX', 'Web Application Development', 'Algorithm', 'Data Structures', 'C++ Programming']"),
#  ('user169@example.com',
#   "['Software Engineering', 'Web Application Development', 'Data Structures', 'Algorithm']"),
#  ('user363@example.com',
#   "['Data Structures', 'Algorithm', 'UI/UX', 'Software Engineering', 'C++ Programming', 'Web Application Development']"),
#  ('user765@example.com', "['Data Structures']"),
#  ('user967@example.com', "['UI/UX', 'C++ Programming']"),
#  ('user128@example.com',
#   "['Data Structures', 'C++ Programming', 'UI/UX', 'Algorithm', 'Software Engineering']"),
#  ('user738@example.com',
#   "['C++ Programming', 'Data Structures', 'Web Application Development', 'Algorithm', 'Software Engineering', 'UI/UX']"),
#  ('user721@example.com', "['C++ Programming']"),
#  ('user553@example.com', "['UI/UX', 'Web Application Development']"),
#  ('user911@example.com',
#   "['C++ Programming', 'UI/UX', 'Software Engineering']"),
#  ('user473@example.com', "['C++ Programming', 'Algorithm']"),
#  ('user273@example.com',
#   "['C++ Programming', 'Algorithm', 'Software Engineering', 'Data Structures', 'UI/UX', 'Web Application Development']"),
#  ('user136@example.com',
#   "['Data Structures', 'UI/UX', 'C++ Programming', 'Algorithm', 'Software Engineering', 'Web Application Development']"),
#  ('user790@example.com', "['Algorithm', 'Software Engineering', 'UI/UX']"),
#  ('user575@example.com',
#   "['Software Engineering', 'Web Application Development', 'UI/UX']"),
#  ('user389@example.com', "['Web Application Development', 'Data Structures']"),
#  ('user512@example.com', "['UI/UX']"),
#  ('user760@example.com', "['Software Engineering']"),
#  ('user891@example.com',
#   "['UI/UX', 'Data Structures', 'C++ Programming', 'Software Engineering', 'Web Application Development', 'Algorithm']"),
#  ('user395@example.com',
#   "['C++ Programming', 'UI/UX', 'Web Application Development', 'Data Structures', 'Software Engineering']"),
#  ('user828@example.com',
#   "['Data Structures', 'Algorithm', 'Software Engineering']"),
#  ('user1000@example.com',
#   "['Data Structures', 'Algorithm', 'C++ Programming']"),
#  ('user315@example.com',
#   "['Web Application Development', 'Data Structures', 'Software Engineering', 'C++ Programming', 'UI/UX', 'Algorithm']"),
#  ('user919@example.com', "['Web Application Development']")]

# %%
# Load project data
projects = []
with open('Projects.csv', 'r') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip the header row
    for row in reader:
        project_id = row[0]
        skills = row[1]
        projects.append((project_id, skills))

# %%
projects
# Out:
# [('project-1',
#   "['C++ Programming', 'Software Engineering', 'Web Application Development', 'Data Structures', 'Algorithm', 'UI/UX']"),
#  ('project-2', "['C++ Programming', 'Algorithm']"),
#  ('project-3', "['UI/UX', 'C++ Programming']"),
#  ('project-4', "['C++ Programming']"),
#  ('project-5',
#   "['Algorithm', 'UI/UX', 'Software Engineering', 'C++ Programming', 'Web Application Development']"),
#  ('project-6',
#   "['Data Structures', 'C++ Programming', 'Algorithm', 'Software Engineering', 'UI/UX', 'Web Application Development']"),
#  ('project-7', "['C++ Programming']"),
#  ('project-8', "['Data Structures', 'Web Application Development']"),
#  ('project-9', "['Software Engineering']"),
#  ('project-10', "['Web Application Development', 'C++ Programming']"),
#  ('project-11', "['Algorithm', 'C++ Programming']"),
#  ('project-12', "['Data Structures']"),
#  ('project-13', "['Web Application Development', 'Software Engineering']"),
#  ('project-14', "['C++ Programming', 'Web Application Development']"),
#  ('project-15', "['Algorithm']"),
#  ('project-16', "['Software Engineering']"),
#  ('project-17', "['C++ Programming', 'Data Structures']"),
#  ('project-18', "['Algorithm', 'C++ Programming', 'UI/UX']"),
#  ('project-19',
#   "['Data Structures', 'C++ Programming', 'Algorithm', 'Software Engineering']"),
#  ('project-20',
#   "['Software Engineering', 'Web Application Development', 'C++ Programming']"),
#  ('project-21',
#   "['Software Engineering', 'UI/UX', 'Web Application Development', 'C++ Programming']"),
#  ('project-22',
#   "['C++ Programming', 'Data Structures', 'Web Application Development']"),
#  ('project-23', "['Software Engineering', 'Algorithm']"),
#  ('project-24',
#   "['C++ Programming', 'UI/UX', 'Software Engineering', 'Algorithm']"),
#  ('project-25', "['Software Engineering']"),
#  ('project-26',
#   "['UI/UX', 'Software Engineering', 'Algorithm', 'Data Structures']"),
#  ('project-27', "['Software Engineering']"),
#  ('project-28',
#   "['Web Application Development', 'Algorithm', 'UI/UX', 'Data Structures']"),
#  ('project-29',
#   "['Software Engineering', 'C++ Programming', 'UI/UX', 'Algorithm', 'Web Application Development', 'Data Structures']"),
#  ('project-30',
#   "['C++ Programming', 'Web Application Development', 'Data Structures', 'Software Engineering', 'Algorithm']"),
#  ('project-31',
#   "['UI/UX', 'Software Engineering', 'Algorithm', 'Data Structures', 'C++ Programming', 'Web Application Development']"),
#  ('project-32', "['Software Engineering', 'Web Application Development']"),
#  ('project-33', "['Data Structures']"),
#  ('project-34',
#   "['Algorithm', 'UI/UX', 'C++ Programming', 'Web Application Development', 'Data Structures']"),
#  ('project-35', "['Web Application Development', 'Data Structures']"),
#  ('project-36', "['Software Engineering']"),
#  ('project-37',
#   "['Web Application Development', 'C++ Programming', 'Data Structures']"),
#  ('project-38',
#   "['C++ Programming', 'Web Application Development', 'Algorithm', 'Software Engineering']"),
#  ('project-39',
#   "['Data Structures', 'Web Application Development', 'Algorithm', 'UI/UX']"),
#  ('project-40',
#   "['C++ Programming', 'Software Engineering', 'Algorithm', 'Web Application Development', 'Data Structures']"),
#  ('project-41', "['UI/UX']"),
#  ('project-42',
#   "['Algorithm', 'C++ Programming', 'Software Engineering', 'Web Application Development']"),
#  ('project-43',
#   "['Web Application Development', 'Algorithm', 'Data Structures', 'Software Engineering', 'C++ Programming', 'UI/UX']"),
#  ('project-44', "['Software Engineering', 'Algorithm']"),
#  ('project-45',
#   "['C++ Programming', 'Algorithm', 'Web Application Development', 'UI/UX', 'Data Structures']"),
#  ('project-46',
#   "['Data Structures', 'Software Engineering', 'UI/UX', 'Web Application Development', 'Algorithm', 'C++ Programming']"),
#  ('project-47', "['UI/UX', 'C++ Programming']"),
#  ('project-48',
#   "['Algorithm', 'C++ Programming', 'Software Engineering', 'Data Structures', 'Web Application Development']"),
#  ('project-49', "['Algorithm']"),
#  ('project-50',
#   "['UI/UX', 'Data Structures', 'Algorithm', 'Web Application Development']"),
#  ('project-51',
#   "['Software Engineering', 'UI/UX', 'Data Structures', 'C++ Programming']"),
#  ('project-52',
#   "['Algorithm', 'Software Engineering', 'Web Application Development', 'C++ Programming', 'UI/UX']"),
#  ('project-53',
#   "['Data Structures', 'Web Application Development', 'Algorithm', 'C++ Programming', 'UI/UX']"),
#  ('project-54',
#   "['UI/UX', 'Data Structures', 'Software Engineering', 'C++ Programming']"),
#  ('project-55',
#   "['Software Engineering', 'UI/UX', 'C++ Programming', 'Algorithm', 'Web Application Development']"),
#  ('project-56', "['Algorithm']"),
#  ('project-57',
#   "['Data Structures', 'C++ Programming', 'UI/UX', 'Software Engineering', 'Algorithm']"),
#  ('project-58',
#   "['UI/UX', 'C++ Programming', 'Web Application Development', 'Software Engineering', 'Algorithm']"),
#  ('project-59',
#   "['Algorithm', 'UI/UX', 'Software Engineering', 'C++ Programming', 'Data Structures', 'Web Application Development']"),
#  ('project-60', "['Data Structures', 'Software Engineering']"),
#  ('project-61', "['UI/UX', 'Web Application Development']"),
#  ('project-62', "['Software Engineering', 'Algorithm']"),
#  ('project-63',
#   "['Data Structures', 'Software Engineering', 'UI/UX', 'Algorithm', 'Web Application Development']"),
#  ('project-64', "['Data Structures', 'Algorithm']"),
#  ('project-65', "['Algorithm', 'Web Application Development']"),
#  ('project-66', "['UI/UX', 'Software Engineering', 'Algorithm']"),
#  ('project-67',
#   "['C++ Programming', 'Data Structures', 'Web Application Development', 'Software Engineering', 'UI/UX']"),
#  ('project-68',
#   "['Software Engineering', 'C++ Programming', 'Data Structures', 'Algorithm']"),
#  ('project-69', "['C++ Programming']"),
#  ('project-70',
#   "['UI/UX', 'Web Application Development', 'Algorithm', 'Data Structures']"),
#  ('project-71', "['Software Engineering', 'Algorithm']"),
#  ('project-72', "['Software Engineering']"),
#  ('project-73',
#   "['C++ Programming', 'Algorithm', 'Web Application Development', 'UI/UX', 'Data Structures', 'Software Engineering']"),
#  ('project-74',
#   "['Software Engineering', 'Web Application Development', 'Algorithm', 'C++ Programming']"),
#  ('project-75',
#   "['UI/UX', 'Data Structures', 'C++ Programming', 'Web Application Development', 'Algorithm']"),
#  ('project-76',
#   "['Data Structures', 'Software Engineering', 'UI/UX', 'Web Application Development', 'Algorithm']"),
#  ('project-77',
#   "['Software Engineering', 'UI/UX', 'Algorithm', 'Data Structures', 'C++ Programming']"),
#  ('project-78',
#   "['Software Engineering', 'Data Structures', 'UI/UX', 'Algorithm', 'Web Application Development']"),
#  ('project-79', "['Web Application Development', 'C++ Programming']"),
#  ('project-80', "['Algorithm', 'Web Application Development']"),
#  ('project-81', "['Data Structures', 'Algorithm']"),
#  ('project-82',
#   "['Software Engineering', 'UI/UX', 'Data Structures', 'Web Application Development']"),
#  ('project-83', "['Data Structures', 'C++ Programming']"),
#  ('project-84',
#   "['Web Application Development', 'Software Engineering', 'C++ Programming']"),
#  ('project-85', "['Web Application Development']"),
#  ('project-86',
#   "['Web Application Development', 'C++ Programming', 'Algorithm', 'Data Structures', 'Software Engineering']"),
#  ('project-87',
#   "['UI/UX', 'Algorithm', 'Software Engineering', 'Data Structures', 'Web Application Development']"),
#  ('project-88', "['Algorithm', 'UI/UX', 'Software Engineering']"),
#  ('project-89',
#   "['UI/UX', 'Software Engineering', 'Data Structures', 'Algorithm']"),
#  ('project-90',
#   "['UI/UX', 'C++ Programming', 'Algorithm', 'Software Engineering', 'Web Application Development', 'Data Structures']"),
#  ('project-91', "['Data Structures']"),
#  ('project-92', "['C++ Programming']"),
#  ('project-93',
#   "['Algorithm', 'C++ Programming', 'UI/UX', 'Web Application Development', 'Software Engineering']"),
#  ('project-94', "['Algorithm']"),
#  ('project-95',
#   "['Web Application Development', 'Data Structures', 'C++ Programming', 'UI/UX', 'Software Engineering']"),
#  ('project-96', "['Algorithm']"),
#  ('project-97',
#   "['Algorithm', 'C++ Programming', 'Software Engineering', 'UI/UX', 'Web Application Development']"),
#  ('project-98',
#   "['Software Engineering', 'Algorithm', 'Web Application Development', 'Data Structures']"),
#  ('project-99',
#   "['Algorithm', 'Web Application Development', 'UI/UX', 'C++ Programming']"),
#  ('project-100', "['UI/UX', 'Algorithm', 'Data Structures']")]

# %%
# Step 2: Preprocess data and compute cosine similarity matrix

# Preprocess skills for CountVectorizer
all_skills = [user[1] for user in users] + [project[1] for project in projects]

# %%
all_skills
# Out:
# ["['C++ Programming']",
#  "['C++ Programming', 'UI/UX', 'Algorithm', 'Software Engineering']",
#  "['Web Application Development', 'UI/UX', 'C++ Programming', 'Algorithm', 'Software Engineering', 'Data Structures']",
#  "['Algorithm']",
#  "['Algorithm', 'UI/UX', 'Software Engineering', 'C++ Programming', 'Web Application Development', 'Data Structures']",
#  "['UI/UX', 'Software Engineering', 'C++ Programming', 'Web Application Development']",
#  "['Web Application Development', 'UI/UX']",
#  "['Algorithm', 'UI/UX', 'Software Engineering', 'Data Structures', 'Web Application Development', 'C++ Programming']",
#  "['C++ Programming', 'UI/UX', 'Algorithm', 'Data Structures', 'Web Application Development']",
#  "['Web Application Development', 'Algorithm']",
#  "['Software Engineering']",
#  "['Web Application Development', 'C++ Programming', 'Software Engineering', 'Algorithm']",
#  "['UI/UX', 'Web Application Development']",
#  "['Data Structures', 'UI/UX', 'Web Application Development', 'C++ Programming', 'Software Engineering']",
#  "['Software Engineering']",
#  "['Data Structures', 'Web Application Development', 'Software Engineering', 'Algorithm']",
#  "['Software Engineering', 'Data Structures', 'Web Application Development', 'C++ Programming', 'UI/UX']",
#  "['Software Engineering', 'C++ Programming', 'Data Structures', 'Algorithm', 'UI/UX']",
#  "['Data Structures', 'Algorithm', 'C++ Programming']",
#  "['Data Structures', 'Algorithm']",
#  "['C++ Programming', 'Web Application Development', 'UI/UX']",
#  "['Data Structures', 'Algorithm']",
#  "['UI/UX', 'Web Application Development', 'Software Engineering']",
#  "['UI/UX', 'Data Structures', 'C++ Programming', 'Web Application Development']",
#  "['C++ Programming']",
#  "['Algorithm', 'Data Structures', 'UI/UX']",
#  "['C++ Programming', 'Web Application Development', 'UI/UX', 'Data Structures', 'Software Engineering']",
#  "['Software Engineering', 'Web Application Development', 'Data Structures', 'UI/UX', 'C++ Programming', 'Algorithm']",
#  "['UI/UX', 'C++ Programming']",
#  "['Algorithm', 'Data Structures', 'Web Application Development']",
#  "['Data Structures', 'UI/UX']",
#  "['Web Application Development', 'Software Engineering', 'C++ Programming']",
#  "['Algorithm']",
#  "['Web Application Development', 'Software Engineering', 'UI/UX', 'Data Structures', 'Algorithm', 'C++ Programming']",
#  "['UI/UX', 'Algorithm']",
#  "['Web Application Development']",
#  "['Software Engineering', 'Web Application Development', 'Data Structures', 'C++ Programming', 'Algorithm', 'UI/UX']",
#  "['Data Structures']",
#  "['Algorithm']",
#  "['Algorithm']",
#  "['C++ Programming', 'Software Engineering', 'Web Application Development']",
#  "['Data Structures']",
#  "['Data Structures', 'UI/UX', 'Software Engineering', 'Web Application Development', 'C++ Programming']",
#  "['C++ Programming', 'Software Engineering', 'Data Structures', 'UI/UX', 'Algorithm']",
#  "['C++ Programming', 'Data Structures', 'Software Engineering', 'UI/UX', 'Web Application Development']",
#  "['UI/UX', 'Data Structures', 'Software Engineering']",
#  "['C++ Programming', 'UI/UX', 'Algorithm']",
#  "['Algorithm', 'Data Structures', 'C++ Programming', 'Web Application Development', 'UI/UX']",
#  "['C++ Programming', 'Algorithm', 'Software Engineering', 'Data Structures', 'UI/UX', 'Web Application Development']",
#  "['C++ Programming', 'Algorithm', 'Software Engineering']",
#  "['Web Application Development', 'Data Structures']",
#  "['Web Application Development', 'Data Structures', 'C++ Programming']",
#  "['UI/UX', 'Algorithm', 'Software Engineering', 'C++ Programming', 'Data Structures', 'Web Application Development']",
#  "['Algorithm', 'Data Structures', 'C++ Programming']",
#  "['Data Structures', 'Software Engineering']",
#  "['Web Application Development', 'C++ Programming']",
#  "['Data Structures', 'Web Application Development', 'UI/UX', 'Software Engineering']",
#  "['UI/UX', 'Web Application Development', 'Data Structures', 'Algorithm']",
#  "['UI/UX', 'Algorithm', 'C++ Programming']",
#  "['Algorithm', 'Data Structures', 'Web Application Development', 'C++ Programming', 'Software Engineering']",
#  "['UI/UX', 'Software Engineering', 'Algorithm', 'Web Application Development', 'Data Structures', 'C++ Programming']",
#  "['Data Structures', 'Algorithm', 'Web Application Development', 'C++ Programming']",
#  "['Data Structures', 'Software Engineering']",
#  "['UI/UX', 'Software Engineering', 'Data Structures']",
#  "['Software Engineering', 'Web Application Development', 'Data Structures']",
#  "['Web Application Development', 'Data Structures', 'C++ Programming', 'Software Engineering']",
#  "['Data Structures', 'Software Engineering', 'Web Application Development', 'UI/UX', 'Algorithm', 'C++ Programming']",
#  "['Data Structures', 'Software Engineering', 'Algorithm', 'Web Application Development', 'UI/UX']",
#  "['Algorithm', 'UI/UX', 'Software Engineering']",
#  "['UI/UX', 'Data Structures', 'Web Application Development', 'C++ Programming']",
#  "['Software Engineering', 'Algorithm']",
#  "['Algorithm']",
#  "['Algorithm', 'Data Structures', 'Software Engineering', 'C++ Programming', 'Web Application Development']",
#  "['C++ Programming', 'Data Structures']",
#  "['Web Application Development', 'UI/UX', 'Algorithm', 'Software Engineering', 'Data Structures', 'C++ Programming']",
#  "['C++ Programming']",
#  "['UI/UX', 'Web Application Development', 'Algorithm', 'Data Structures', 'C++ Programming']",
#  "['Software Engineering', 'Web Application Development', 'Data Structures', 'Algorithm']",
#  "['Data Structures', 'Algorithm', 'UI/UX', 'Software Engineering', 'C++ Programming', 'Web Application Development']",
#  "['Data Structures']",
#  "['UI/UX', 'C++ Programming']",
#  "['Data Structures', 'C++ Programming', 'UI/UX', 'Algorithm', 'Software Engineering']",
#  "['C++ Programming', 'Data Structures', 'Web Application Development', 'Algorithm', 'Software Engineering', 'UI/UX']",
#  "['C++ Programming']",
#  "['UI/UX', 'Web Application Development']",
#  "['C++ Programming', 'UI/UX', 'Software Engineering']",
#  "['C++ Programming', 'Algorithm']",
#  "['C++ Programming', 'Algorithm', 'Software Engineering', 'Data Structures', 'UI/UX', 'Web Application Development']",
#  "['Data Structures', 'UI/UX', 'C++ Programming', 'Algorithm', 'Software Engineering', 'Web Application Development']",
#  "['Algorithm', 'Software Engineering', 'UI/UX']",
#  "['Software Engineering', 'Web Application Development', 'UI/UX']",
#  "['Web Application Development', 'Data Structures']",
#  "['UI/UX']",
#  "['Software Engineering']",
#  "['UI/UX', 'Data Structures', 'C++ Programming', 'Software Engineering', 'Web Application Development', 'Algorithm']",
#  "['C++ Programming', 'UI/UX', 'Web Application Development', 'Data Structures', 'Software Engineering']",
#  "['Data Structures', 'Algorithm', 'Software Engineering']",
#  "['Data Structures', 'Algorithm', 'C++ Programming']",
#  "['Web Application Development', 'Data Structures', 'Software Engineering', 'C++ Programming', 'UI/UX', 'Algorithm']",
#  "['Web Application Development']",
#  "['C++ Programming', 'Software Engineering', 'Web Application Development', 'Data Structures', 'Algorithm', 'UI/UX']",
#  "['C++ Programming', 'Algorithm']",
#  "['UI/UX', 'C++ Programming']",
#  "['C++ Programming']",
#  "['Algorithm', 'UI/UX', 'Software Engineering', 'C++ Programming', 'Web Application Development']",
#  "['Data Structures', 'C++ Programming', 'Algorithm', 'Software Engineering', 'UI/UX', 'Web Application Development']",
#  "['C++ Programming']",
#  "['Data Structures', 'Web Application Development']",
#  "['Software Engineering']",
#  "['Web Application Development', 'C++ Programming']",
#  "['Algorithm', 'C++ Programming']",
#  "['Data Structures']",
#  "['Web Application Development', 'Software Engineering']",
#  "['C++ Programming', 'Web Application Development']",
#  "['Algorithm']",
#  "['Software Engineering']",
#  "['C++ Programming', 'Data Structures']",
#  "['Algorithm', 'C++ Programming', 'UI/UX']",
#  "['Data Structures', 'C++ Programming', 'Algorithm', 'Software Engineering']",
#  "['Software Engineering', 'Web Application Development', 'C++ Programming']",
#  "['Software Engineering', 'UI/UX', 'Web Application Development', 'C++ Programming']",
#  "['C++ Programming', 'Data Structures', 'Web Application Development']",
#  "['Software Engineering', 'Algorithm']",
#  "['C++ Programming', 'UI/UX', 'Software Engineering', 'Algorithm']",
#  "['Software Engineering']",
#  "['UI/UX', 'Software Engineering', 'Algorithm', 'Data Structures']",
#  "['Software Engineering']",
#  "['Web Application Development', 'Algorithm', 'UI/UX', 'Data Structures']",
#  "['Software Engineering', 'C++ Programming', 'UI/UX', 'Algorithm', 'Web Application Development', 'Data Structures']",
#  "['C++ Programming', 'Web Application Development', 'Data Structures', 'Software Engineering', 'Algorithm']",
#  "['UI/UX', 'Software Engineering', 'Algorithm', 'Data Structures', 'C++ Programming', 'Web Application Development']",
#  "['Software Engineering', 'Web Application Development']",
#  "['Data Structures']",
#  "['Algorithm', 'UI/UX', 'C++ Programming', 'Web Application Development', 'Data Structures']",
#  "['Web Application Development', 'Data Structures']",
#  "['Software Engineering']",
#  "['Web Application Development', 'C++ Programming', 'Data Structures']",
#  "['C++ Programming', 'Web Application Development', 'Algorithm', 'Software Engineering']",
#  "['Data Structures', 'Web Application Development', 'Algorithm', 'UI/UX']",
#  "['C++ Programming', 'Software Engineering', 'Algorithm', 'Web Application Development', 'Data Structures']",
#  "['UI/UX']",
#  "['Algorithm', 'C++ Programming', 'Software Engineering', 'Web Application Development']",
#  "['Web Application Development', 'Algorithm', 'Data Structures', 'Software Engineering', 'C++ Programming', 'UI/UX']",
#  "['Software Engineering', 'Algorithm']",
#  "['C++ Programming', 'Algorithm', 'Web Application Development', 'UI/UX', 'Data Structures']",
#  "['Data Structures', 'Software Engineering', 'UI/UX', 'Web Application Development', 'Algorithm', 'C++ Programming']",
#  "['UI/UX', 'C++ Programming']",
#  "['Algorithm', 'C++ Programming', 'Software Engineering', 'Data Structures', 'Web Application Development']",
#  "['Algorithm']",
#  "['UI/UX', 'Data Structures', 'Algorithm', 'Web Application Development']",
#  "['Software Engineering', 'UI/UX', 'Data Structures', 'C++ Programming']",
#  "['Algorithm', 'Software Engineering', 'Web Application Development', 'C++ Programming', 'UI/UX']",
#  "['Data Structures', 'Web Application Development', 'Algorithm', 'C++ Programming', 'UI/UX']",
#  "['UI/UX', 'Data Structures', 'Software Engineering', 'C++ Programming']",
#  "['Software Engineering', 'UI/UX', 'C++ Programming', 'Algorithm', 'Web Application Development']",
#  "['Algorithm']",
#  "['Data Structures', 'C++ Programming', 'UI/UX', 'Software Engineering', 'Algorithm']",
#  "['UI/UX', 'C++ Programming', 'Web Application Development', 'Software Engineering', 'Algorithm']",
#  "['Algorithm', 'UI/UX', 'Software Engineering', 'C++ Programming', 'Data Structures', 'Web Application Development']",
#  "['Data Structures', 'Software Engineering']",
#  "['UI/UX', 'Web Application Development']",
#  "['Software Engineering', 'Algorithm']",
#  "['Data Structures', 'Software Engineering', 'UI/UX', 'Algorithm', 'Web Application Development']",
#  "['Data Structures', 'Algorithm']",
#  "['Algorithm', 'Web Application Development']",
#  "['UI/UX', 'Software Engineering', 'Algorithm']",
#  "['C++ Programming', 'Data Structures', 'Web Application Development', 'Software Engineering', 'UI/UX']",
#  "['Software Engineering', 'C++ Programming', 'Data Structures', 'Algorithm']",
#  "['C++ Programming']",
#  "['UI/UX', 'Web Application Development', 'Algorithm', 'Data Structures']",
#  "['Software Engineering', 'Algorithm']",
#  "['Software Engineering']",
#  "['C++ Programming', 'Algorithm', 'Web Application Development', 'UI/UX', 'Data Structures', 'Software Engineering']",
#  "['Software Engineering', 'Web Application Development', 'Algorithm', 'C++ Programming']",
#  "['UI/UX', 'Data Structures', 'C++ Programming', 'Web Application Development', 'Algorithm']",
#  "['Data Structures', 'Software Engineering', 'UI/UX', 'Web Application Development', 'Algorithm']",
#  "['Software Engineering', 'UI/UX', 'Algorithm', 'Data Structures', 'C++ Programming']",
#  "['Software Engineering', 'Data Structures', 'UI/UX', 'Algorithm', 'Web Application Development']",
#  "['Web Application Development', 'C++ Programming']",
#  "['Algorithm', 'Web Application Development']",
#  "['Data Structures', 'Algorithm']",
#  "['Software Engineering', 'UI/UX', 'Data Structures', 'Web Application Development']",
#  "['Data Structures', 'C++ Programming']",
#  "['Web Application Development', 'Software Engineering', 'C++ Programming']",
#  "['Web Application Development']",
#  "['Web Application Development', 'C++ Programming', 'Algorithm', 'Data Structures', 'Software Engineering']",
#  "['UI/UX', 'Algorithm', 'Software Engineering', 'Data Structures', 'Web Application Development']",
#  "['Algorithm', 'UI/UX', 'Software Engineering']",
#  "['UI/UX', 'Software Engineering', 'Data Structures', 'Algorithm']",
#  "['UI/UX', 'C++ Programming', 'Algorithm', 'Software Engineering', 'Web Application Development', 'Data Structures']",
#  "['Data Structures']",
#  "['C++ Programming']",
#  "['Algorithm', 'C++ Programming', 'UI/UX', 'Web Application Development', 'Software Engineering']",
#  "['Algorithm']",
#  "['Web Application Development', 'Data Structures', 'C++ Programming', 'UI/UX', 'Software Engineering']",
#  "['Algorithm']",
#  "['Algorithm', 'C++ Programming', 'Software Engineering', 'UI/UX', 'Web Application Development']",
#  "['Software Engineering', 'Algorithm', 'Web Application Development', 'Data Structures']",
#  "['Algorithm', 'Web Application Development', 'UI/UX', 'C++ Programming']",
#  "['UI/UX', 'Algorithm', 'Data Structures']"]

# %%
# Create CountVectorizer and fit-transform the skills
vectorizer = CountVectorizer()
skills_matrix = vectorizer.fit_transform(all_skills)

# %%
# Compute cosine similarity matrix
user_skills = skills_matrix[:len(users)]
project_skills = skills_matrix[len(users):]
cosine_sim_matrix = cosine_similarity(user_skills, project_skills)

# %%
user_skills
# Out:
# <100x11 sparse matrix of type '<class 'numpy.int64'>'
# 	with 620 stored elements in Compressed Sparse Row format>

# %%
project_skills
# Out:
# <100x11 sparse matrix of type '<class 'numpy.int64'>'
# 	with 590 stored elements in Compressed Sparse Row format>

# %%
cosine_sim_matrix
# Out:
# array([[0.30151134, 0.70710678, 0.57735027, ..., 0.        , 0.37796447,
#         0.        ],
#        [0.73854895, 0.57735027, 0.70710678, ..., 0.4330127 , 0.6172134 ,
#         0.54772256],
#        [1.        , 0.42640143, 0.52223297, ..., 0.85280287, 0.79772404,
#         0.67419986],
#        ...,
#        [0.60302269, 0.70710678, 0.28867513, ..., 0.53033009, 0.37796447,
#         0.67082039],
#        [1.        , 0.42640143, 0.52223297, ..., 0.85280287, 0.79772404,
#         0.67419986],
#        [0.52223297, 0.        , 0.        , ..., 0.61237244, 0.65465367,
#         0.        ]])

# %%
# Step 3: Generate recommendations and write to Cosine_sim.csv

# Write recommendations to Cosine_sim.csv
with open('Cosine_sim.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Email', 'Recommended Projects'])

    for user_index, user in enumerate(users):
        email = user[0]

        # Get cosine similarity scores for the user
        user_sim_scores = cosine_sim_matrix[user_index]

        # Sort projects based on similarity scores
        sorted_indices = user_sim_scores.argsort()[::-1]

        # Get top 15 recommended projects
        num_projects = min(15, len(projects))
        recommended_projects = [projects[i][0] for i in sorted_indices[:num_projects]]

        writer.writerow([email, recommended_projects])
